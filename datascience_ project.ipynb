# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.io as pio
import plotly.express as px

# %%
dataset=pd.read_csv("Inputdata - Sheet1.csv")

# %%
dataset
# Out:
#                                         Campaign name        Day  \
# 0                         ForeignSales-AsiaAntartrica  3/31/2024
# 1                                         Feedbackrs9  3/31/2024
# 2                         ForeignSales-AsiaAntartrica  3/29/2024
# 3                                         Feedbackrs9  3/28/2024
# 4                         ForeignSales-AsiaAntartrica  3/27/2024
# 5                         ForeignSales-AsiaAntartrica  3/26/2024
# 6                                         Feedbackrs9  3/26/2024
# 7                         ForeignSales-AsiaAntartrica  3/25/2024
# 8                         ForeignSales-AsiaAntartrica  3/24/2024
# 9                                         Feedbackrs9  3/24/2024
# 10                                        Feedbackrs9  3/23/2024
# 11                        ForeignSales-AsiaAntartrica  3/23/2024
# 12                        ForeignSales-AsiaAntartrica  3/22/2024
# ...

# %%
dataset.isnull().sum()
# Out:
# Campaign name                          0
# Day                                    0
# Delivery status                        0
# Delivery level                         0
# Amount spent (INR)                     0
# Impressions                            0
# CPM (cost per 1,000 impressions)      20
# Reach                                  0
# Frequency                              0
# CTR (link click-through rate)         20
# Video plays                           20
# Video plays at 100%                   20
# CTR (all)                             20
# Link clicks                           20
# Landing page views                    20
# Result Type                           18
# Results                               17
# Purchase ROAS (return on ad spend)    35
# Attribution setting                    0
# Cost per result                       18
# Reporting starts                       0
# Reporting ends                         0
# dtype: int64

# %%
dataset.fillna(0, inplace=True)

# %%
dataset.isnull().sum()
# Out:
# Campaign name                         0
# Day                                   0
# Delivery status                       0
# Delivery level                        0
# Amount spent (INR)                    0
# Impressions                           0
# CPM (cost per 1,000 impressions)      0
# Reach                                 0
# Frequency                             0
# CTR (link click-through rate)         0
# Video plays                           0
# Video plays at 100%                   0
# CTR (all)                             0
# Link clicks                           0
# Landing page views                    0
# Result Type                           0
# Results                               0
# Purchase ROAS (return on ad spend)    0
# Attribution setting                   0
# Cost per result                       0
# Reporting starts                      0
# Reporting ends                        0
# dtype: int64

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 46 entries, 0 to 45
# Data columns (total 22 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   Campaign name                       46 non-null     object
#  1   Day                                 46 non-null     object
#  2   Delivery status                     46 non-null     object
#  3   Delivery level                      46 non-null     object
#  4   Amount spent (INR)                  46 non-null     float64
#  5   Impressions                         46 non-null     int64
#  6   CPM (cost per 1,000 impressions)    46 non-null     float64
#  7   Reach                               46 non-null     int64
#  8   Frequency                           46 non-null     float64
#  9   CTR (link click-through rate)       46 non-null     float64
#  10  Video plays                         46 non-null     float64
# ...

# %%
dataset.columns
# Out:
# Index(['Campaign name', 'Day', 'Delivery status', 'Delivery level',
#        'Amount spent (INR)', 'Impressions', 'CPM (cost per 1,000 impressions)',
#        'Reach', 'Frequency', 'CTR (link click-through rate)', 'Video plays',
#        'Video plays at 100%', 'CTR (all)', 'Link clicks', 'Landing page views',
#        'Result Type', 'Results', 'Purchase ROAS (return on ad spend)',
#        'Attribution setting', 'Cost per result', 'Reporting starts',
#        'Reporting ends'],
#       dtype='object')

# %%
num_days = 31  # Change this to the number of days you need
# Create a date range
date_range = pd.date_range(start='2024-03-01', periods=num_days)

# Format dates
formatted_dates = [date.strftime('%d %b (%a)') for date in date_range]

# Create DataFrame
df = pd.DataFrame({'Date': formatted_dates})
df
# Out:
#             Date
# 0   01 Mar (Fri)
# 1   02 Mar (Sat)
# 2   03 Mar (Sun)
# 3   04 Mar (Mon)
# 4   05 Mar (Tue)
# 5   06 Mar (Wed)
# 6   07 Mar (Thu)
# 7   08 Mar (Fri)
# 8   09 Mar (Sat)
# 9   10 Mar (Sun)
# 10  11 Mar (Mon)
# 11  12 Mar (Tue)
# 12  13 Mar (Wed)
# 13  14 Mar (Thu)
# 14  15 Mar (Fri)
# 15  16 Mar (Sat)
# 16  17 Mar (Sun)
# 17  18 Mar (Mon)
# 18  19 Mar (Tue)
# 19  20 Mar (Wed)
# 20  21 Mar (Thu)
# 21  22 Mar (Fri)
# 22  23 Mar (Sat)
# 23  24 Mar (Sun)
# 24  25 Mar (Mon)
# 25  26 Mar (Tue)
# 26  27 Mar (Wed)
# 27  28 Mar (Thu)
# 28  29 Mar (Fri)
# 29  30 Mar (Sat)
# 30  31 Mar (Sun)

# %%
dataset['Cost per lead'] = dataset['Amount spent (INR)'] / dataset['Results']

# %%
dataset['Member passed']=dataset['Landing page views']/dataset['Link clicks']

# %%
dataset['Member passed']*100
# Out:
# 0     46.907216
# 1     63.636364
# 2           NaN
# 3           NaN
# 4           NaN
# 5           NaN
# 6           NaN
# 7           NaN
# 8     53.591160
# 9     66.326531
# 10    70.588235
# 11    70.503597
# 12    56.716418
# 13    70.297030
# 14          NaN
# 15    52.857143
# 16    81.081081
# 17          NaN
# 18    75.555556
# 19    81.521739
# 20    64.444444
# 21    63.291139
# 22    85.714286
# 23    64.948454
# 24    83.720930
# 25    80.000000
# 26    75.471698
# 27    75.862069
# 28          NaN
# 29          NaN
# 30          NaN
# 31          NaN
# 32          NaN
# 33          NaN
# 34          NaN
# 35          NaN
# 36          NaN
# 37    81.081081
# 38    76.744186
# 39          NaN
# 40          NaN
# 41    44.444444
# 42    76.704545
# 43          NaN
# 44    82.936508
# 45    56.250000
# Name: Member passed, dtype: float64

# %%
dataset.fillna(0, inplace=True)

# %%
dataset
# Out:
#                                         Campaign name        Day  \
# 0                         ForeignSales-AsiaAntartrica 2024-03-31
# 1                                         Feedbackrs9 2024-03-31
# 2                         ForeignSales-AsiaAntartrica 2024-03-29
# 3                                         Feedbackrs9 2024-03-28
# 4                         ForeignSales-AsiaAntartrica 2024-03-27
# 5                         ForeignSales-AsiaAntartrica 2024-03-26
# 6                                         Feedbackrs9 2024-03-26
# 7                         ForeignSales-AsiaAntartrica 2024-03-25
# 8                         ForeignSales-AsiaAntartrica 2024-03-24
# 9                                         Feedbackrs9 2024-03-24
# 10                                        Feedbackrs9 2024-03-23
# 11                        ForeignSales-AsiaAntartrica 2024-03-23
# 12                        ForeignSales-AsiaAntartrica 2024-03-22
# ...

# %%
dataset['LP Conversion']=dataset['Results']/dataset['Landing page views']

# %%
dataset['LP Conversion']*100
# Out:
# 0      9.890110
# 1      7.142857
# 2           inf
# 3           NaN
# 4           inf
# 5           inf
# 6           NaN
# 7           inf
# 8      6.185567
# 9      7.692308
# 10    20.833333
# 11     4.081633
# 12     0.000000
# 13    15.492958
# 14          NaN
# 15     4.054054
# 16    22.222222
# 17          NaN
# 18     3.921569
# 19    14.666667
# 20    20.689655
# 21     4.000000
# 22     0.000000
# 23    15.873016
# 24     0.000000
# 25    26.250000
# 26     0.000000
# 27     0.000000
# 28          inf
# 29          NaN
# 30          NaN
# 31          inf
# 32          NaN
# 33          NaN
# 34          inf
# 35          NaN
# 36          inf
# 37     0.000000
# 38     8.080808
# 39          NaN
# 40          inf
# 41    37.500000
# 42     3.703704
# 43          inf
# 44     5.741627
# 45     0.000000
# Name: LP Conversion, dtype: float64

# %%
dataset['LP Conversion'] = dataset['LP Conversion'].replace([np.inf, -np.inf], 0)
dataset['Cost per lead'] = dataset['Cost per lead'].replace([np.inf, -np.inf], 0)

# %%
dataset['LP Conversion'] = dataset['LP Conversion'].fillna(0)
dataset['Cost per lead'] = dataset['Cost per lead'].fillna(0)

# %%
dataset
# Out:
#                                         Campaign name        Day  \
# 0                                 Foreign|Sales|Tamil 2024-03-01
# 1   3dayslive – Copy 2 - Advantage+ shopping campaign 2024-03-01
# 2                                    3dayslive – Copy 2024-03-01
# 3   3dayslive – Copy 2 - Advantage+ shopping campaign 2024-03-02
# 4                                 Foreign|Sales|Tamil 2024-03-02
# 5                                 Foreign|Sales|Tamil 2024-03-03
# 6                                    3dayslive – Copy 2024-03-03
# 7   3dayslive – Copy 2 - Advantage+ shopping campaign 2024-03-03
# 8   Foreign|Sales|Tamil - Advantage+ shopping camp... 2024-03-03
# 9                                 Foreign|Sales|Tamil 2024-03-04
# 10                                   3dayslive – Copy 2024-03-04
# 11  3dayslive – Copy 2 - Advantage+ shopping campaign 2024-03-04
# 12                                   3dayslive – Copy 2024-03-05
# ...

# %%
#dataset['Date']=dataset['Day']

# %%
dataset.sort_values(by='Day', inplace=True)

# Assign the sorted 'Day' column to the 'Date' column
dataset['Date'] = dataset['Day']

# %%
dataset
# Out:
#                                         Campaign name        Day  \
# 0                                 Foreign|Sales|Tamil 2024-03-01
# 1   3dayslive – Copy 2 - Advantage+ shopping campaign 2024-03-01
# 2                                    3dayslive – Copy 2024-03-01
# 3   3dayslive – Copy 2 - Advantage+ shopping campaign 2024-03-02
# 4                                 Foreign|Sales|Tamil 2024-03-02
# 5                                 Foreign|Sales|Tamil 2024-03-03
# 6                                    3dayslive – Copy 2024-03-03
# 7   3dayslive – Copy 2 - Advantage+ shopping campaign 2024-03-03
# 8   Foreign|Sales|Tamil - Advantage+ shopping camp... 2024-03-03
# 11  3dayslive – Copy 2 - Advantage+ shopping campaign 2024-03-04
# 10                                   3dayslive – Copy 2024-03-04
# 9                                 Foreign|Sales|Tamil 2024-03-04
# 12                                   3dayslive – Copy 2024-03-05
# ...

# %%
dataset['Date'] = pd.to_datetime(dataset['Date'])

# Format the date column to display in the desired format
formatted_dates = dataset['Date'].dt.strftime('%d %b (%a)')

# Assign the formatted dates back to the 'Date' column
dataset['Date'] = formatted_dates

# %%
import pandas as pd

# Assuming df is your exist,ng DataFrame
# Fetch columns 'column1', 'column2', 'column3'
selected_columns = ['Date','Campaign name', 'Amount spent (INR)', 'Results','CTR (all)','Link clicks','Landing page views','Cost per lead','Member passed','LP Conversion']
new_df = dataset[selected_columns].copy()

# %%
new_df
# Out:
#             Date                                      Campaign name  \
# 0   01 Mar (Fri)                                Foreign|Sales|Tamil
# 1   01 Mar (Fri)  3dayslive – Copy 2 - Advantage+ shopping campaign
# 2   01 Mar (Fri)                                   3dayslive – Copy
# 3   02 Mar (Sat)  3dayslive – Copy 2 - Advantage+ shopping campaign
# 4   02 Mar (Sat)                                Foreign|Sales|Tamil
# 5   03 Mar (Sun)                                Foreign|Sales|Tamil
# 6   03 Mar (Sun)                                   3dayslive – Copy
# 7   03 Mar (Sun)  3dayslive – Copy 2 - Advantage+ shopping campaign
# 8   03 Mar (Sun)  Foreign|Sales|Tamil - Advantage+ shopping camp...
# 11  04 Mar (Mon)  3dayslive – Copy 2 - Advantage+ shopping campaign
# 10  04 Mar (Mon)                                   3dayslive – Copy
# 9   04 Mar (Mon)                                Foreign|Sales|Tamil
# 12  05 Mar (Tue)                                   3dayslive – Copy
# ...

# %%
new_df.reset_index(drop=True, inplace=True)

# %%
new_df
# Out:
#             Date                                      Campaign name  \
# 0   01 Mar (Fri)                                Foreign|Sales|Tamil
# 1   01 Mar (Fri)  3dayslive – Copy 2 - Advantage+ shopping campaign
# 2   01 Mar (Fri)                                   3dayslive – Copy
# 3   02 Mar (Sat)  3dayslive – Copy 2 - Advantage+ shopping campaign
# 4   02 Mar (Sat)                                Foreign|Sales|Tamil
# 5   03 Mar (Sun)                                Foreign|Sales|Tamil
# 6   03 Mar (Sun)                                   3dayslive – Copy
# 7   03 Mar (Sun)  3dayslive – Copy 2 - Advantage+ shopping campaign
# 8   03 Mar (Sun)  Foreign|Sales|Tamil - Advantage+ shopping camp...
# 9   04 Mar (Mon)  3dayslive – Copy 2 - Advantage+ shopping campaign
# 10  04 Mar (Mon)                                   3dayslive – Copy
# 11  04 Mar (Mon)                                Foreign|Sales|Tamil
# 12  05 Mar (Tue)                                   3dayslive – Copy
# ...

# %%
new_df= new_df.rename(columns={'Amount spent (INR)': 'AD Spent', 'Results': 'No. of Leads','CTR (all)':'CTR'})

# %%
new_df
# Out:
#             Date                                      Campaign name  AD Spent  \
# 0   01 Mar (Fri)                                Foreign|Sales|Tamil    484.26
# 1   01 Mar (Fri)  3dayslive – Copy 2 - Advantage+ shopping campaign   1899.99
# 2   01 Mar (Fri)                                   3dayslive – Copy      0.00
# 3   02 Mar (Sat)  3dayslive – Copy 2 - Advantage+ shopping campaign   1896.02
# 4   02 Mar (Sat)                                Foreign|Sales|Tamil    384.46
# 5   03 Mar (Sun)                                Foreign|Sales|Tamil      0.00
# 6   03 Mar (Sun)                                   3dayslive – Copy      0.00
# 7   03 Mar (Sun)  3dayslive – Copy 2 - Advantage+ shopping campaign   1520.26
# 8   03 Mar (Sun)  Foreign|Sales|Tamil - Advantage+ shopping camp...    391.27
# 11  04 Mar (Mon)  3dayslive – Copy 2 - Advantage+ shopping campaign      0.00
# 10  04 Mar (Mon)                                   3dayslive – Copy      0.00
# ...

# %%
campaign_name_to_fetch = 'Feedbackrs9'

# Filter the DataFrame to fetch details for the specified campaign name
campaign_details = new_df.loc[dataset['Campaign name'] == campaign_name_to_fetch]

# Print the details for the specified campaign name

# %%
campaign_details
# Out:
#             Date Campaign name  AD Spent  No. of Leads       CTR  Link clicks  \
# 20  17 Mar (Sun)   Feedbackrs9   1941.11          21.0  1.376637        100.0
# 22  18 Mar (Mon)   Feedbackrs9   2001.02          10.0  1.203008         97.0
# 24  19 Mar (Tue)   Feedbackrs9   2009.33          18.0  1.192236        135.0
# 26  20 Mar (Wed)   Feedbackrs9   1997.54          11.0  0.982502         92.0
# 29  21 Mar (Thu)   Feedbackrs9   1982.31          20.0  1.047451        111.0
# 32  22 Mar (Fri)   Feedbackrs9   1983.00          11.0  0.787817        101.0
# 34  23 Mar (Sat)   Feedbackrs9   1941.17          15.0  0.938745        102.0
# 36  24 Mar (Sun)   Feedbackrs9   1573.42           5.0  1.022956         98.0
# 39  26 Mar (Tue)   Feedbackrs9      0.00           0.0  0.000000          0.0
# 42  28 Mar (Thu)   Feedbackrs9      0.00           0.0  0.000000          0.0
# 44  31 Mar (Sun)   Feedbackrs9    497.70           1.0  0.865951         22.0
#
# ...
